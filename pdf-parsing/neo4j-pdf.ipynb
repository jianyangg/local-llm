# %%
import os

import streamlit as st
from langchain.chains import create_retrieval_chain
from PyPDF2 import PdfReader
from langchain.callbacks.base import BaseCallbackHandler
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import Neo4jVector
from streamlit.logger import get_logger
from langchain_community.embeddings import OllamaEmbeddings
from langchain_community.chat_models import ChatOllama
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate
from typing import Dict, List

# %%
config={"ollama_base_url": "http://localhost:11434",
        "llm_name": "llama3",
        "neo4j_url": "neo4j://localhost:7687",
        "neo4j_username": "neo4j",
        "neo4j_password": "password",
        "pdf_path": "data/mcbook-user-guide.pdf",		
        }

# %%
# load embedding model
embeddings = OllamaEmbeddings(
    base_url=config["ollama_base_url"],	
    model=config["llm_name"]
)

# %%
# load the llm
llm = ChatOllama(
            temperature=0,
            base_url=config["ollama_base_url"],
            model=config["llm_name"],
            streaming=True,
            # seed=2,
            top_k=10,  # A higher value (100) will give more diverse answers, while a lower value (10) will be more conservative.
            top_p=0.3,  # Higher value (0.95) will lead to more diverse text, while a lower value (0.5) will generate more focused text.
            num_ctx=3072,  # Sets the size of the context window used to generate the next token.
        )

# %% [markdown]
# ## Version 1 begins here.

# %% [markdown]
# ##### TODO: This functionality can be generalised for different file types (i.e., do a check on the file extension perhaps but that may not work in i.e., Linux)

# %%
# load the pdf
pdf_path = config["pdf_path"]
pdf_reader = PdfReader(pdf_path)
print(len(pdf_reader.pages))
# Out:
# 76

# %%
# prepare textual data from pdf for the model
text = ""
for page in pdf_reader.pages:
    text += page.extract_text()

# langchain_textspliter
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000, chunk_overlap=200, length_function=len
)

# %%
# Splitting into chunks and saving metadata for easier reference / verification of information

# prepare textual data from pdf for the model
text_chunks_with_metadata: List[Dict] = []
for page_num, page in enumerate(pdf_reader.pages, start=1):  # Start from page 1
    page_text = page.extract_text()
    page_chunks = text_splitter.split_text(text=page_text)
    for chunk_num, chunk in enumerate(page_chunks):
        text_chunks_with_metadata.append({
            "text": chunk,
            "page_num": page_num,
            "chunk_num": chunk_num,
            "start_pos": page_text.find(chunk),  # Find starting position within page
            "pdf_path": pdf_path
        })

# %%
# Store the chunks part in db (vector)
vectorstore = Neo4jVector.from_texts(
    # Texts represents the new data and will be supplemented with the initial data
    texts=[chunk_data["text"] for chunk_data in text_chunks_with_metadata],
    url=config["neo4j_url"], #database url
    username=config["neo4j_username"], #neo4j username
    password=config["neo4j_password"], #neo4j password
    embedding=embeddings, #embedding model from load_embedding_model
    index_name="pdf_reader", #index name
    node_label="pdfTrial", #node label
    # TODO: REMOVE THIS LINE to retain the vector database
    pre_delete_collection=True,  # Delete existing PDF data
    metadatas=text_chunks_with_metadata  # Pass the metadata list directly
)

# %%
retriever = vectorstore.as_retriever()

# %%
retriever.invoke("Wifi")
# Out:
# [Document(page_content='3\n3 Problem, Meet Solution\nwww.apple.com/support\nMac Help help', metadata={'pdf_path': 'data/mcbook-user-guide.pdf', 'page_num': 39, 'chunk_num': 0, 'start_pos': 0}),
#  Document(page_content='1 \n1  \nReady, Set Up, Go\nwww.apple.com/macbookair\nMac Help Migration Assistant', metadata={'pdf_path': 'data/mcbook-user-guide.pdf', 'page_num': 7, 'chunk_num': 0, 'start_pos': 2}),
#  Document(page_content='56 Chapter 3   Problem, Meet SolutionLocating  Your Product  Serial Number\nUse one of these methods to find your computer’s serial number:\nÂTurn your MacBook Air over. The serial number is etched into the case, near the \nhinge. \nÂChoose Apple ( \uf8ff) > About This Mac and then click the version number beneath the \nwords “Mac OS X.” Clicking cycles between the Mac OS X version number, the build version, and the serial number. \nÂOpen System Profiler (in /Applications/Utilities/) and click Hardware.Serial number', metadata={'pdf_path': 'data/mcbook-user-guide.pdf', 'page_num': 56, 'chunk_num': 0, 'start_pos': 2}),
#  Document(page_content='Chapter 3   Problem, Meet Solution 55Your 90 days of complimentary telephone support begins on the date of purchase and \ntelephone fees may apply. \nTelephone numbers are subject to change, and local and national telephone rates may \napply. A complete list is available on the web:Country Phone Website\nUnited States 1-800-275-2273 www.apple.com/support\nAustralia (61) 133-622 www.apple.com/au/support\nCanada (English)\n(French)1-800-263-3394 www.apple.com/ca/support\nwww.apple.com/ca/fr/support\nIreland (353) 1850 946 191 www.apple.com/ie/supportNew Zealand 00800-7666-7666 www.apple.com/nz/supportUnited Kingdom (44) 0870 876 0753 www.apple.com/uk/support\nwww.apple.com/contact/phone_contacts.htmlwww.apple.com/contact/phone_contacts.html', metadata={'pdf_path': 'data/mcbook-user-guide.pdf', 'page_num': 55, 'chunk_num': 0, 'start_pos': 2})]

# %% [markdown]
# #### Direct querying using a basic RAG workflow (without agents and LangGraph)

# %%
prompt = ChatPromptTemplate.from_template("""Answer the following question based only on the provided context:

<context>
{context}
</context>

Question: {input}""")

# chain takes in context and input and returns the output
document_chain = create_stuff_documents_chain(llm, prompt)
retriever = vectorstore.as_retriever()
retrieval_chain = create_retrieval_chain(retriever, document_chain)

# %%
response = retrieval_chain.invoke({"input": "What is the Macbook Command Center?"})
print(response)
# Out:
# {'input': 'What is the Macbook Command Center?', 'context': [Document(page_content='To get Mac Help:\n1Click the Finder icon in the Dock (the bar of icons along the edge of the screen).\n2Click the Help menu in the menu bar and do one of the following:\naType a question or term in the Search field, and select a topic from the returned list \nor select Show All Results to see all topics.\nbChoose Mac Help to open the Mac Help window, where you can click links or type a \nsearch question.', metadata={'pdf_path': 'data/mcbook-user-guide.pdf', 'page_num': 35, 'chunk_num': 1, 'start_pos': 814}), Document(page_content='ÂFor the latest information about Mac OS X, go to www.apple.com/macosx.\nLearning  More, Service,  and Support\nYour MacBook Air does not have any user-serviceable or user-replaceable parts. If you \nneed service, contact Apple or take your MacBook Air to an Apple Authorized Service Provider. You can find more information about the MacBook Air through online resources, onscreen help, System Profiler, or Apple Hardware Test.\nOnline Resources\nFor online service and support information, go to www.apple.com/support. Choose your country from the pop-up menu. You can search the AppleCare Knowledge Base, check for software updates, or get help on Apple’s discussion forums.', metadata={'pdf_path': 'data/mcbook-user-guide.pdf', 'page_num': 53, 'chunk_num': 1, 'start_pos': 682}), Document(page_content='36 Chapter 2   Life with Your MacBook AirMore Information\nFor more information about using your MacBook Air, see the following:\nTo learn about Do this\nTroubleshooting your \nMacBook Air if you have a \nproblemSee Chapter 3, “Problem, Meet Solution,” on page 39.\nFinding service and support \nfor your MacBook AirSee “Learning More, Service, and Support” on page 53. Or go to the \nApple Support website at www.apple.com/support/macbookair.\nUsing Mac OS X Go to the Mac OS X website at www.apple.com/macosx. \nOr search for “Mac OS X” in Mac Help. \nMoving from a PC to a Mac See “How To Move To Mac” at www.apple.com/getamac/\nmovetomac.\nUsing iLife ’08 applications Go to the iLife ’08 website at www.apple.com/ilife. Or open an iLife \n’08 application, open Help for the application, and then type a question in the search field.\nChanging System \nPreferencesOpen System Preferences by choosing Apple (\nK) > System \nPreferences. Or search for “system preferences” in Mac Help.', metadata={'pdf_path': 'data/mcbook-user-guide.pdf', 'page_num': 36, 'chunk_num': 0, 'start_pos': 2}), Document(page_content='Chapter 3   Problem, Meet Solution 45Reinstalling  Software  Using Remote  Install  Mac OS X\nUse Remote Install Mac OS X on the partner computer whose optical disc drive you \nwant to share (installation instructions for this and other components of the DVD or CD Sharing Setup software are on page 15) when you want to do one of the following tasks on your MacBook Air:\nÂReinstall Mac OS X and other software that came with your MacBook Air\nÂReset your password\nÂUse Disk Utility to repair the MacBook Air hard disk\nNote:  You can also do these tasks using a MacBook Air SuperDrive (available separately \nat www.apple.com/store). See page 49.', metadata={'pdf_path': 'data/mcbook-user-guide.pdf', 'page_num': 45, 'chunk_num': 0, 'start_pos': 2})], 'answer': 'There is no mention of a "MacBook Command Center" in the provided context. The context only discusses various ways to access help and support for the MacBook Air, including using the Finder icon, the Help menu, and online resources.'}

# %%
print(response["answer"])
# Out:
# There is no mention of a "MacBook Command Center" in the provided context. The context only discusses various ways to access help and support for the MacBook Air, including using the Finder icon, the Help menu, and online resources.

# %%
print(response.keys())
# Out:
# dict_keys(['input', 'context', 'answer'])

# %%
# obtain the documents referenced
print(">> Context")
context = response["context"]
print("Context:", context)
print("Context length:", len(context))
print()
print(">> Documents fetched (context, broken down)")
for doc in context:
    print("Document:", doc)
    print("Metadata:", doc.metadata)
    print()
# Out:
# >> Context
# Context: [Document(page_content='To get Mac Help:\n1Click the Finder icon in the Dock (the bar of icons along the edge of the screen).\n2Click the Help menu in the menu bar and do one of the following:\naType a question or term in the Search field, and select a topic from the returned list \nor select Show All Results to see all topics.\nbChoose Mac Help to open the Mac Help window, where you can click links or type a \nsearch question.', metadata={'pdf_path': 'data/mcbook-user-guide.pdf', 'page_num': 35, 'chunk_num': 1, 'start_pos': 814}), Document(page_content='ÂFor the latest information about Mac OS X, go to www.apple.com/macosx.\nLearning  More, Service,  and Support\nYour MacBook Air does not have any user-serviceable or user-replaceable parts. If you \nneed service, contact Apple or take your MacBook Air to an Apple Authorized Service Provider. You can find more information about the MacBook Air through online resources, onscreen help, System Profiler, or Apple Hardware Test.\nOnline Resources\nFor online service and support information, go to www.apple.com/support. Choose your country from the pop-up menu. You can search the AppleCare Knowledge Base, check for software updates, or get help on Apple’s discussion forums.', metadata={'pdf_path': 'data/mcbook-user-guide.pdf', 'page_num': 53, 'chunk_num': 1, 'start_pos': 682}), Document(page_content='36 Chapter 2   Life with Your MacBook AirMore Information\nFor more information about using your MacBook Air, see the following:\nTo learn about Do this\nTroubleshooting your \nMacBook Air if you have a \nproblemSee Chapter 3, “Problem, Meet Solution,” on page 39.\nFinding service and support \nfor your MacBook AirSee “Learning More, Service, and Support” on page 53. Or go to the \nApple Support website at www.apple.com/support/macbookair.\nUsing Mac OS X Go to the Mac OS X website at www.apple.com/macosx. \nOr search for “Mac OS X” in Mac Help. \nMoving from a PC to a Mac See “How To Move To Mac” at www.apple.com/getamac/\nmovetomac.\nUsing iLife ’08 applications Go to the iLife ’08 website at www.apple.com/ilife. Or open an iLife \n’08 application, open Help for the application, and then type a question in the search field.\nChanging System \nPreferencesOpen System Preferences by choosing Apple (\nK) > System \nPreferences. Or search for “system preferences” in Mac Help.', metadata={'pdf_path': 'data/mcbook-user-guide.pdf', 'page_num': 36, 'chunk_num': 0, 'start_pos': 2}), Document(page_content='Chapter 3   Problem, Meet Solution 45Reinstalling  Software  Using Remote  Install  Mac OS X\nUse Remote Install Mac OS X on the partner computer whose optical disc drive you \nwant to share (installation instructions for this and other components of the DVD or CD Sharing Setup software are on page 15) when you want to do one of the following tasks on your MacBook Air:\nÂReinstall Mac OS X and other software that came with your MacBook Air\nÂReset your password\nÂUse Disk Utility to repair the MacBook Air hard disk\nNote:  You can also do these tasks using a MacBook Air SuperDrive (available separately \nat www.apple.com/store). See page 49.', metadata={'pdf_path': 'data/mcbook-user-guide.pdf', 'page_num': 45, 'chunk_num': 0, 'start_pos': 2})]
# Context length: 4
#
# >> Documents fetched (context, broken down)
# Document: page_content='To get Mac Help:\n1Click the Finder icon in the Dock (the bar of icons along the edge of the screen).\n2Click the Help menu in the menu bar and do one of the following:\naType a question or term in the Search field, and select a topic from the returned list \nor select Show All Results to see all topics.\nbChoose Mac Help to open the Mac Help window, where you can click links or type a \nsearch question.' metadata={'pdf_path': 'data/mcbook-user-guide.pdf', 'page_num': 35, 'chunk_num': 1, 'start_pos': 814}
# Metadata: {'pdf_path': 'data/mcbook-user-guide.pdf', 'page_num': 35, 'chunk_num': 1, 'start_pos': 814}
#
# Document: page_content='ÂFor the latest information about Mac OS X, go to www.apple.com/macosx.\nLearning  More, Service,  and Support\nYour MacBook Air does not have any user-serviceable or user-replaceable parts. If you \nneed service, contact Apple or take your MacBook Air to an Apple Authorized Service Provider. You can find more information about the MacBook Air through online resources, onscreen help, System Profiler, or Apple Hardware Test.\nOnline Resources\nFor online service and support information, go to www.apple.com/support. Choose your country from the pop-up menu. You can search the AppleCare Knowledge Base, check for software updates, or get help on Apple’s discussion forums.' metadata={'pdf_path': 'data/mcbook-user-guide.pdf', 'page_num': 53, 'chunk_num': 1, 'start_pos': 682}
# Metadata: {'pdf_path': 'data/mcbook-user-guide.pdf', 'page_num': 53, 'chunk_num': 1, 'start_pos': 682}
#
# Document: page_content='36 Chapter 2   Life with Your MacBook AirMore Information\nFor more information about using your MacBook Air, see the following:\nTo learn about Do this\nTroubleshooting your \nMacBook Air if you have a \nproblemSee Chapter 3, “Problem, Meet Solution,” on page 39.\nFinding service and support \nfor your MacBook AirSee “Learning More, Service, and Support” on page 53. Or go to the \nApple Support website at www.apple.com/support/macbookair.\nUsing Mac OS X Go to the Mac OS X website at www.apple.com/macosx. \nOr search for “Mac OS X” in Mac Help. \nMoving from a PC to a Mac See “How To Move To Mac” at www.apple.com/getamac/\nmovetomac.\nUsing iLife ’08 applications Go to the iLife ’08 website at www.apple.com/ilife. Or open an iLife \n’08 application, open Help for the application, and then type a question in the search field.\nChanging System \nPreferencesOpen System Preferences by choosing Apple (\nK) > System \nPreferences. Or search for “system preferences” in Mac Help.' metadata={'pdf_path': 'data/mcbook-user-guide.pdf', 'page_num': 36, 'chunk_num': 0, 'start_pos': 2}
# Metadata: {'pdf_path': 'data/mcbook-user-guide.pdf', 'page_num': 36, 'chunk_num': 0, 'start_pos': 2}
#
# Document: page_content='Chapter 3   Problem, Meet Solution 45Reinstalling  Software  Using Remote  Install  Mac OS X\nUse Remote Install Mac OS X on the partner computer whose optical disc drive you \nwant to share (installation instructions for this and other components of the DVD or CD Sharing Setup software are on page 15) when you want to do one of the following tasks on your MacBook Air:\nÂReinstall Mac OS X and other software that came with your MacBook Air\nÂReset your password\nÂUse Disk Utility to repair the MacBook Air hard disk\nNote:  You can also do these tasks using a MacBook Air SuperDrive (available separately \nat www.apple.com/store). See page 49.' metadata={'pdf_path': 'data/mcbook-user-guide.pdf', 'page_num': 45, 'chunk_num': 0, 'start_pos': 2}
# Metadata: {'pdf_path': 'data/mcbook-user-guide.pdf', 'page_num': 45, 'chunk_num': 0, 'start_pos': 2}

# %% [markdown]
# ## Version 2 begins here.

# %% [markdown]
# ### Determining a good parser instead of PyPDF2 used earlier ^^

# %% [markdown]
# ##### !! LLM Sherpa is good for PDF, XML, and HTML files.

# %%
# testing llm sherpa
from langchain_community.document_loaders.llmsherpa import LLMSherpaFileLoader

# %%
loader = LLMSherpaFileLoader(
    file_path="data/website.html",
    new_indent_parser=True,
    apply_ocr=True,
    strategy="chunks",
    llmsherpa_api_url="http://localhost:5010/api/parseDocument?renderFormat=all",
)
docs = loader.load()

# %%
from pprint import pprint

# %%
pprint(docs)
# Out:
# [Document(page_content='\nSkip to main content', metadata={'source': 'data/website.html', 'chunk_number': 0, 'chunk_type': 'para'}),
#  Document(page_content='\nOpen navigation', metadata={'source': 'data/website.html', 'chunk_number': 1, 'chunk_type': 'para'}),
#  Document(page_content='\nGo to Reddit Home', metadata={'source': 'data/website.html', 'chunk_number': 2, 'chunk_type': 'para'}),
#  Document(page_content='\nr/MachineLearning\n \n \n \n    \n \n \nA chip\nA close button', metadata={'source': 'data/website.html', 'chunk_number': 3, 'chunk_type': 'para'}),
#  Document(page_content='\nGet app\nGet the Reddit app', metadata={'source': 'data/website.html', 'chunk_number': 4, 'chunk_type': 'para'}),
#  Document(page_content='\nLog In\nLog in to Reddit', metadata={'source': 'data/website.html', 'chunk_number': 5, 'chunk_type': 'para'}),
#  Document(page_content='\nOpen settings menu\nLog In / Sign Up\nAdvertise on Reddit\nShop Collectible Avatars', metadata={'source': 'data/website.html', 'chunk_number': 6, 'chunk_type': 'para'}),
#  Document(page_content='\n          Get the Reddit app\n        \nScan this QR code to download the app now', metadata={'source': 'data/website.html', 'chunk_number': 7, 'chunk_type': 'para'}),
#  Document(page_content='\n          Get the Reddit app\n        \n \n \n \n        Go to MachineLearning\n \n \n \n \nr/MachineLearning\nr/MachineLearning\n \n \n \n        ml.\nBeginners please see learnmachinelearning\n \n \n \n \nMembers\nOnline\n•\nross_prager\n \n \n  ADMIN\n \n \n  MOD', metadata={'source': 'data/website.html', 'chunk_number': 8, 'chunk_type': 'para'}),
#  Document(page_content='\n [R] LLM for Word Document Parsing - optimal approach \n\nResearch', metadata={'source': 'data/website.html', 'chunk_number': 9, 'chunk_type': 'para'}),
#  Document(page_content='\n [R] LLM for Word Document Parsing - optimal approach \n\nHoping to get some help from the community here!', metadata={'source': 'data/website.html', 'chunk_number': 10, 'chunk_type': 'para'}),
#  Document(page_content='\n [R] LLM for Word Document Parsing - optimal approach \n\n \n \nI want to automatically and accurately identify headings for a document and the text contained in each heading.\nThe structure of these documents varies, and the headings may even very between documents slightly.\nThe overall goal is to create a high level structure of the document that could then be re-arranged automatically.', metadata={'source': 'data/website.html', 'chunk_number': 11, 'chunk_type': 'para'}),
#  Document(page_content='\n [R] LLM for Word Document Parsing - optimal approach \n\n \n \nI am thinking that LLMs might be a good way to do this, but wondering if any one has specific recommendations about how best to approach this.\nAny thoughts on GPT4 vs. GPT3.5 vs. Anthropic models.', metadata={'source': 'data/website.html', 'chunk_number': 12, 'chunk_type': 'para'}),
#  Document(page_content='\n [R] LLM for Word Document Parsing - optimal approach \n\nThanks in advance for the pearls\n&nbsp;\n&nbsp;\nTOPICS\nInternet Culture (Viral)\nAmazing\nAnimals & Pets\nCringe & Facepalm\nFunny\nInteresting\nMemes\nOddly Satisfying\nReddit Meta\nWholesome & Heartwarming\nGames\nAction Games\nAdventure Games\nEsports\nGaming Consoles & Gear\nGaming News & Discussion\nMobile Games\nOther Games\nRole-Playing Games\nSimulation Games\nSports & Racing Games\nStrategy Games\nTabletop Games\nQ&As\nQ&As\nStories & Confessions\nTechnology\n3D Printing\nArtificial Intelligence & Machine Learning\nComputers & Hardware\nConsumer Electronics\nDIY Electronics\nProgramming\nSoftware & Apps\nStreaming Services\nTech News & Discussion\nVirtual & Augmented Reality\nPop Culture\nCelebrities\nCreators & Influencers\nGenerations & Nostalgia\nPodcasts\nStreamers\nTarot & Astrology\nMovies & TV\nAction Movies & Series\nAnimated Movies & Series\nComedy Movies & Series\nCrime, Mystery, & Thriller Movies & Series\nDocumentary Movies & Series\nDrama Movies & Series\nFantasy Movies & Series\nHorror Movies & Series\nMovie News & Discussion\nReality TV\nRomance Movies & Series\nSci-Fi Movies & Series\nSuperhero Movies & Series\nTV News & Discussion\nRESOURCES\nAbout Reddit\nAdvertise\nHelp\nBlog\nCareers\nPress\nCommunities\nBest of Reddit\nTopics\nContent Policy\nPrivacy Policy\nUser Agreement', metadata={'source': 'data/website.html', 'chunk_number': 13, 'chunk_type': 'para'})]

# %%
pprint(docs[0])
# Out:
# Document(page_content='\nSkip to main content', metadata={'source': 'data/website.html', 'chunk_number': 0, 'chunk_type': 'para'})

# %% [markdown]
# ##### !! However, for DOCX files, LLMSherpa somehow unable to read it. Instead, we use python-docx

# %%
from docx import Document as wordDocument
from langchain.docstore.document import Document as LangchainDocument

file_name = "data/word.docx"
doc = wordDocument(file_name)
doc_splits = []
para_num = 0
for para in doc.paragraphs:
    # Check if para.text is empty
    if not para.text:
        continue
    
    # convert into langchain document
    # langchain document only has page_content and metadata
    # within metadata, we store the source, chunk_number, and chunk_type
    # para and chunk are used interchangeably here. can be improved.
    langchain_doc = LangchainDocument(page_content=para.text, metadata={"source": file_name, "chunk_number": para_num, "chunk_type": "para"})
    doc_splits.append(langchain_doc)
    para_num += 1

pprint(doc_splits)
# Out:
# [Document(page_content='[Congressional Record Volume 170, Number 41 (Thursday, March 7, 2024)]', metadata={'source': 'data/word.docx', 'chunk_number': 0, 'chunk_type': 'para'}),
#  Document(page_content='[Senate]', metadata={'source': 'data/word.docx', 'chunk_number': 1, 'chunk_type': 'para'}),
#  Document(page_content='[Pages S2272-S2277]', metadata={'source': 'data/word.docx', 'chunk_number': 2, 'chunk_type': 'para'}),
#  Document(page_content='From the Congressional Record Online through the Government Publishing Office [www.gpo.gov]', metadata={'source': 'data/word.docx', 'chunk_number': 3, 'chunk_type': 'para'}),
#  Document(page_content='                          PRESIDENTIAL MESSAGE', metadata={'source': 'data/word.docx', 'chunk_number': 4, 'chunk_type': 'para'}),
#  Document(page_content='                                 ______', metadata={'source': 'data/word.docx', 'chunk_number': 5, 'chunk_type': 'para'}),
#  Document(page_content='                                 ', metadata={'source': 'data/word.docx', 'chunk_number': 6, 'chunk_type': 'para'}),
#  Document(page_content='   REPORT ON THE STATE OF THE UNION DELIVERED TO A JOINT SESSION OF ', metadata={'source': 'data/word.docx', 'chunk_number': 7, 'chunk_type': 'para'}),
#  Document(page_content='                    CONGRESS ON MARCH 7, 2024--PM 41', metadata={'source': 'data/word.docx', 'chunk_number': 8, 'chunk_type': 'para'}),
#  Document(page_content='  The PRESIDING OFFICER laid before the Senate the following message ', metadata={'source': 'data/word.docx', 'chunk_number': 9, 'chunk_type': 'para'}),
#  Document(page_content='from the President of the United States which was ordered to lie on the ', metadata={'source': 'data/word.docx', 'chunk_number': 10, 'chunk_type': 'para'}),
#  Document(page_content='table:', metadata={'source': 'data/word.docx', 'chunk_number': 11, 'chunk_type': 'para'}),
#  Document(page_content='To the Congress of the United States:', metadata={'source': 'data/word.docx', 'chunk_number': 12, 'chunk_type': 'para'}),
#  Document(page_content='  Good evening. Mr. Speaker. Madam Vice President. Members of Congress. ', metadata={'source': 'data/word.docx', 'chunk_number': 13, 'chunk_type': 'para'}),
#  Document(page_content='My Fellow Americans.', metadata={'source': 'data/word.docx', 'chunk_number': 14, 'chunk_type': 'para'}),
#  Document(page_content='  In January 1941--President Franklin Roosevelt came to this chamber to ', metadata={'source': 'data/word.docx', 'chunk_number': 15, 'chunk_type': 'para'}),
#  Document(page_content='speak to the Nation. He said---``I address you at a moment ', metadata={'source': 'data/word.docx', 'chunk_number': 16, 'chunk_type': 'para'}),
#  Document(page_content='unprecedented', metadata={'source': 'data/word.docx', 'chunk_number': 17, 'chunk_type': 'para'}),
#  Document(page_content='[[Page S2273]]', metadata={'source': 'data/word.docx', 'chunk_number': 18, 'chunk_type': 'para'}),
#  Document(page_content="in the history of the Union''. Hitler was on the march. War was raging ", metadata={'source': 'data/word.docx', 'chunk_number': 19, 'chunk_type': 'para'}),
#  Document(page_content="in Europe. President Roosevelt's purpose was to wake up the Congress ", metadata={'source': 'data/word.docx', 'chunk_number': 20, 'chunk_type': 'para'}),
#  Document(page_content='and alert the American people that this was no ordinary moment. Freedom ', metadata={'source': 'data/word.docx', 'chunk_number': 21, 'chunk_type': 'para'}),
#  Document(page_content='and democracy were under assault in the world.', metadata={'source': 'data/word.docx', 'chunk_number': 22, 'chunk_type': 'para'}),
#  Document(page_content='  Tonight--I come to the same chamber to address the Nation. Now it is ', metadata={'source': 'data/word.docx', 'chunk_number': 23, 'chunk_type': 'para'}),
#  Document(page_content='we who face an unprecedented moment in the history of the Union. And ', metadata={'source': 'data/word.docx', 'chunk_number': 24, 'chunk_type': 'para'}),
#  Document(page_content='yes--my purpose tonight is to both wake up this Congress and alert the ', metadata={'source': 'data/word.docx', 'chunk_number': 25, 'chunk_type': 'para'}),
#  Document(page_content='American people that this is no ordinary moment either.', metadata={'source': 'data/word.docx', 'chunk_number': 26, 'chunk_type': 'para'}),
#  Document(page_content='  Not since President Lincoln and the Civil War have freedom and ', metadata={'source': 'data/word.docx', 'chunk_number': 27, 'chunk_type': 'para'}),
#  Document(page_content='democracy been under assault here at home as they are today. What makes ', metadata={'source': 'data/word.docx', 'chunk_number': 28, 'chunk_type': 'para'}),
#  Document(page_content='our moment rare is that freedom and democracy are under attack both at ', metadata={'source': 'data/word.docx', 'chunk_number': 29, 'chunk_type': 'para'}),
#  Document(page_content='home and overseas at the very same time.', metadata={'source': 'data/word.docx', 'chunk_number': 30, 'chunk_type': 'para'}),
#  Document(page_content='  Overseas--Putin of Russia--is on the march. Invading Ukraine--and ', metadata={'source': 'data/word.docx', 'chunk_number': 31, 'chunk_type': 'para'}),
#  Document(page_content='sowing chaos throughout Europe and beyond. If anybody in this room ', metadata={'source': 'data/word.docx', 'chunk_number': 32, 'chunk_type': 'para'}),
#  Document(page_content='thinks Putin will stop at Ukraine--I assure you--he will not.', metadata={'source': 'data/word.docx', 'chunk_number': 33, 'chunk_type': 'para'}),
#  Document(page_content='  But Ukraine can stop Putin--if we stand with Ukraine. And provide the ', metadata={'source': 'data/word.docx', 'chunk_number': 34, 'chunk_type': 'para'}),
#  Document(page_content='weapons it needs to defend itself. That is all Ukraine is asking. They ', metadata={'source': 'data/word.docx', 'chunk_number': 35, 'chunk_type': 'para'}),
#  Document(page_content='are not asking for American soldiers. In fact--there are no American ', metadata={'source': 'data/word.docx', 'chunk_number': 36, 'chunk_type': 'para'}),
#  Document(page_content='soldiers at war in Ukraine. And I am determined to keep it that way.', metadata={'source': 'data/word.docx', 'chunk_number': 37, 'chunk_type': 'para'}),
#  Document(page_content='  But now--assistance for Ukraine is being blocked by those who want us ', metadata={'source': 'data/word.docx', 'chunk_number': 38, 'chunk_type': 'para'}),
#  Document(page_content="to walk away from our leadership in the world. It wasn't that long ago ", metadata={'source': 'data/word.docx', 'chunk_number': 39, 'chunk_type': 'para'}),
#  Document(page_content='when a Republican President--Ronald Reagan--thundered--``Mr. ', metadata={'source': 'data/word.docx', 'chunk_number': 40, 'chunk_type': 'para'}),
#  Document(page_content="Gorbachev--tear down this wall''.", metadata={'source': 'data/word.docx', 'chunk_number': 41, 'chunk_type': 'para'}),
#  Document(page_content='  Now--my predecessor--a former Republican President--tells Putin--``Do ', metadata={'source': 'data/word.docx', 'chunk_number': 42, 'chunk_type': 'para'}),
#  Document(page_content="whatever the hell you want.'' A former American President actually said ", metadata={'source': 'data/word.docx', 'chunk_number': 43, 'chunk_type': 'para'}),
#  Document(page_content="that--bowing down--to a Russian leader. It's outrageous. It's ", metadata={'source': 'data/word.docx', 'chunk_number': 44, 'chunk_type': 'para'}),
#  Document(page_content="dangerous. It's unacceptable.", metadata={'source': 'data/word.docx', 'chunk_number': 45, 'chunk_type': 'para'}),
#  Document(page_content='  America is a founding member of NATO--the military alliance of ', metadata={'source': 'data/word.docx', 'chunk_number': 46, 'chunk_type': 'para'}),
#  Document(page_content='democratic nations--created after World War II to prevent war and keep ', metadata={'source': 'data/word.docx', 'chunk_number': 47, 'chunk_type': 'para'}),
#  Document(page_content='the peace.', metadata={'source': 'data/word.docx', 'chunk_number': 48, 'chunk_type': 'para'}),
#  Document(page_content="  Today--I've made NATO stronger than ever. We welcomed Finland to the ", metadata={'source': 'data/word.docx', 'chunk_number': 49, 'chunk_type': 'para'}),
#  Document(page_content='Alliance last year. And just this morning--Sweden officially joined ', metadata={'source': 'data/word.docx', 'chunk_number': 50, 'chunk_type': 'para'}),
#  Document(page_content='NATO--and their Prime Minister--is here tonight.', metadata={'source': 'data/word.docx', 'chunk_number': 51, 'chunk_type': 'para'}),
#  Document(page_content='  Mr. Prime Minister--welcome to NATO--the strongest military alliance ', metadata={'source': 'data/word.docx', 'chunk_number': 52, 'chunk_type': 'para'}),
#  Document(page_content='the world has ever known.', metadata={'source': 'data/word.docx', 'chunk_number': 53, 'chunk_type': 'para'}),
#  Document(page_content='  I say this to Congress--we must stand up to Putin. Send me the ', metadata={'source': 'data/word.docx', 'chunk_number': 54, 'chunk_type': 'para'}),
#  Document(page_content='Bipartisan National Security Bill. History is watching. If the United ', metadata={'source': 'data/word.docx', 'chunk_number': 55, 'chunk_type': 'para'}),
#  Document(page_content='States walks away now--it will put Ukraine at risk. Europe at risk. The ', metadata={'source': 'data/word.docx', 'chunk_number': 56, 'chunk_type': 'para'}),
#  Document(page_content='free world at risk--emboldening others who wish to do us harm.', metadata={'source': 'data/word.docx', 'chunk_number': 57, 'chunk_type': 'para'}),
#  Document(page_content='  My message to President Putin is simple. We will not walk away. We ', metadata={'source': 'data/word.docx', 'chunk_number': 58, 'chunk_type': 'para'}),
#  Document(page_content='will not bow down. I will not bow down. History is watching.', metadata={'source': 'data/word.docx', 'chunk_number': 59, 'chunk_type': 'para'}),
#  Document(page_content='  Just like history watched 3 years ago on January 6th. ', metadata={'source': 'data/word.docx', 'chunk_number': 60, 'chunk_type': 'para'}),
#  Document(page_content='Insurrectionists stormed this very Capitol and placed a dagger at the ', metadata={'source': 'data/word.docx', 'chunk_number': 61, 'chunk_type': 'para'}),
#  Document(page_content='throat of American democracy. Many of you were here on that darkest of ', metadata={'source': 'data/word.docx', 'chunk_number': 62, 'chunk_type': 'para'}),
#  Document(page_content='days. We all saw with our own eyes these insurrectionists were not ', metadata={'source': 'data/word.docx', 'chunk_number': 63, 'chunk_type': 'para'}),
#  Document(page_content='patriots. They had come to stop the peaceful transfer of power and to ', metadata={'source': 'data/word.docx', 'chunk_number': 64, 'chunk_type': 'para'}),
#  Document(page_content='overturn the will of the people.', metadata={'source': 'data/word.docx', 'chunk_number': 65, 'chunk_type': 'para'}),
#  Document(page_content='  January 6th--the lies about the 2020 election--and the plots to steal ', metadata={'source': 'data/word.docx', 'chunk_number': 66, 'chunk_type': 'para'}),
#  Document(page_content='the election--posed the gravest threat to our democracy since the Civil ', metadata={'source': 'data/word.docx', 'chunk_number': 67, 'chunk_type': 'para'}),
#  Document(page_content='War.', metadata={'source': 'data/word.docx', 'chunk_number': 68, 'chunk_type': 'para'}),
#  Document(page_content='  But they failed. America stood strong--and democracy prevailed. But ', metadata={'source': 'data/word.docx', 'chunk_number': 69, 'chunk_type': 'para'}),
#  Document(page_content='we must be honest--the threat remains--and democracy must be defended.', metadata={'source': 'data/word.docx', 'chunk_number': 70, 'chunk_type': 'para'}),
#  Document(page_content='  My predecessor and some of you here--seek to bury the truth of ', metadata={'source': 'data/word.docx', 'chunk_number': 71, 'chunk_type': 'para'}),
#  Document(page_content='January 6th. I will not do that. This is a moment--to speak the truth ', metadata={'source': 'data/word.docx', 'chunk_number': 72, 'chunk_type': 'para'}),
#  Document(page_content="and bury the lies. And here's the simplest truth. You can't love your ", metadata={'source': 'data/word.docx', 'chunk_number': 73, 'chunk_type': 'para'}),
#  Document(page_content='country--only when you win.', metadata={'source': 'data/word.docx', 'chunk_number': 74, 'chunk_type': 'para'}),
#  Document(page_content="  As I've done ever since being elected to office--I ask you all--", metadata={'source': 'data/word.docx', 'chunk_number': 75, 'chunk_type': 'para'}),
#  Document(page_content='without regard to party--to join together--and defend our democracy! ', metadata={'source': 'data/word.docx', 'chunk_number': 76, 'chunk_type': 'para'}),
#  Document(page_content='Remember--your oath of office--to defend against all threats--foreign ', metadata={'source': 'data/word.docx', 'chunk_number': 77, 'chunk_type': 'para'}),
#  Document(page_content='and domestic. Respect free and fair elections! Restore trust in our ', metadata={'source': 'data/word.docx', 'chunk_number': 78, 'chunk_type': 'para'}),
#  Document(page_content='institutions! And make clear--political violence--has no place in ', metadata={'source': 'data/word.docx', 'chunk_number': 79, 'chunk_type': 'para'}),
#  Document(page_content='America! History is watching.', metadata={'source': 'data/word.docx', 'chunk_number': 80, 'chunk_type': 'para'}),
#  Document(page_content='  And history is watching another assault on freedom. Joining us ', metadata={'source': 'data/word.docx', 'chunk_number': 81, 'chunk_type': 'para'}),
#  Document(page_content='tonight--is Latorya Beasley--a social worker from Birmingham, Alabama. ', metadata={'source': 'data/word.docx', 'chunk_number': 82, 'chunk_type': 'para'}),
#  Document(page_content='14 months ago tonight--she and her husband welcomed a baby girl--thanks ', metadata={'source': 'data/word.docx', 'chunk_number': 83, 'chunk_type': 'para'}),
#  Document(page_content='to the miracle of IVF. She scheduled treatments to have a second child. ', metadata={'source': 'data/word.docx', 'chunk_number': 84, 'chunk_type': 'para'}),
#  Document(page_content='But the Alabama Supreme Court shut down IVF treatments across the State ', metadata={'source': 'data/word.docx', 'chunk_number': 85, 'chunk_type': 'para'}),
#  Document(page_content='unleashed by the Supreme Court decision overturning Roe v. Wade. She ', metadata={'source': 'data/word.docx', 'chunk_number': 86, 'chunk_type': 'para'}),
#  Document(page_content='was told her dream would have to wait. What her family has gone through ', metadata={'source': 'data/word.docx', 'chunk_number': 87, 'chunk_type': 'para'}),
#  Document(page_content='should never have happened. And unless the Congress acts--it could ', metadata={'source': 'data/word.docx', 'chunk_number': 88, 'chunk_type': 'para'}),
#  Document(page_content='happen again.', metadata={'source': 'data/word.docx', 'chunk_number': 89, 'chunk_type': 'para'}),
#  Document(page_content="  So tonight--let's stand up for families like hers! To my friends ", metadata={'source': 'data/word.docx', 'chunk_number': 90, 'chunk_type': 'para'}),
#  Document(page_content="across the aisle--don't keep families waiting any longer. Guarantee the ", metadata={'source': 'data/word.docx', 'chunk_number': 91, 'chunk_type': 'para'}),
#  Document(page_content='right to IVF nationwide!', metadata={'source': 'data/word.docx', 'chunk_number': 92, 'chunk_type': 'para'}),
#  Document(page_content='  Like most Americans--I believe--Roe v. Wade got it right. And I thank ', metadata={'source': 'data/word.docx', 'chunk_number': 93, 'chunk_type': 'para'}),
#  Document(page_content='Vice President Harris for being an incredible leader defending ', metadata={'source': 'data/word.docx', 'chunk_number': 94, 'chunk_type': 'para'}),
#  Document(page_content='reproductive freedom and so much more.', metadata={'source': 'data/word.docx', 'chunk_number': 95, 'chunk_type': 'para'}),
#  Document(page_content='  But my predecessor--came to office determined to see Roe v. Wade ', metadata={'source': 'data/word.docx', 'chunk_number': 96, 'chunk_type': 'para'}),
#  Document(page_content="overturned. He's the reason it was. In fact--he brags about it. Look at ", metadata={'source': 'data/word.docx', 'chunk_number': 97, 'chunk_type': 'para'}),
#  Document(page_content='the chaos.', metadata={'source': 'data/word.docx', 'chunk_number': 98, 'chunk_type': 'para'}),
#  Document(page_content='  Joining us tonight is Kate Cox--a wife and mother from Dallas. When ', metadata={'source': 'data/word.docx', 'chunk_number': 99, 'chunk_type': 'para'}),
#  Document(page_content='she became pregnant again the fetus had a fatal condition. Her doctors ', metadata={'source': 'data/word.docx', 'chunk_number': 100, 'chunk_type': 'para'}),
#  Document(page_content='told Kate that her own life--and her ability to have children in the ', metadata={'source': 'data/word.docx', 'chunk_number': 101, 'chunk_type': 'para'}),
#  Document(page_content='future--were at risk. Because Texas law banned abortion Kate and her ', metadata={'source': 'data/word.docx', 'chunk_number': 102, 'chunk_type': 'para'}),
#  Document(page_content='husband had to leave the State to get the care she needed. What her ', metadata={'source': 'data/word.docx', 'chunk_number': 103, 'chunk_type': 'para'}),
#  Document(page_content='family has gone through should never have happened as well.', metadata={'source': 'data/word.docx', 'chunk_number': 104, 'chunk_type': 'para'}),
#  Document(page_content='  But it is happening to so many others. There are State laws banning ', metadata={'source': 'data/word.docx', 'chunk_number': 105, 'chunk_type': 'para'}),
#  Document(page_content='abortion--criminalizing doctors--and forcing survivors of rape and ', metadata={'source': 'data/word.docx', 'chunk_number': 106, 'chunk_type': 'para'}),
#  Document(page_content='incest to leave their States as well.', metadata={'source': 'data/word.docx', 'chunk_number': 107, 'chunk_type': 'para'}),
#  Document(page_content='  Many of you in this chamber--and my predecessor--are promising to ', metadata={'source': 'data/word.docx', 'chunk_number': 108, 'chunk_type': 'para'}),
#  Document(page_content='pass a national ban on reproductive freedom. My God--what freedoms will ', metadata={'source': 'data/word.docx', 'chunk_number': 109, 'chunk_type': 'para'}),
#  Document(page_content='you take next?', metadata={'source': 'data/word.docx', 'chunk_number': 110, 'chunk_type': 'para'}),
#  Document(page_content='  In its decision to overturn Roe v. Wade--the Supreme Court majority ', metadata={'source': 'data/word.docx', 'chunk_number': 111, 'chunk_type': 'para'}),
#  Document(page_content="wrote--``Women are not without electoral or political power.'' No ", metadata={'source': 'data/word.docx', 'chunk_number': 112, 'chunk_type': 'para'}),
#  Document(page_content='kidding. Clearly those bragging about overturning Roe v. Wade have no ', metadata={'source': 'data/word.docx', 'chunk_number': 113, 'chunk_type': 'para'}),
#  Document(page_content='clue about the power of women in America.', metadata={'source': 'data/word.docx', 'chunk_number': 114, 'chunk_type': 'para'}),
#  Document(page_content='  They found out though--when reproductive freedom was on the ballot ', metadata={'source': 'data/word.docx', 'chunk_number': 115, 'chunk_type': 'para'}),
#  Document(page_content='and won--in 2022--2023--and they will find out again--in 2024. If ', metadata={'source': 'data/word.docx', 'chunk_number': 116, 'chunk_type': 'para'}),
#  Document(page_content='Americans send me a Congress that supports the right to choose--I ', metadata={'source': 'data/word.docx', 'chunk_number': 117, 'chunk_type': 'para'}),
#  Document(page_content='promise you--I will restore Roe v. Wade--as the law of the land--again!', metadata={'source': 'data/word.docx', 'chunk_number': 118, 'chunk_type': 'para'}),
#  Document(page_content='  America--cannot go back. I am here tonight--to show the way forward. ', metadata={'source': 'data/word.docx', 'chunk_number': 119, 'chunk_type': 'para'}),
#  Document(page_content="Because I know how far we've come. Four years ago next week--before I ", metadata={'source': 'data/word.docx', 'chunk_number': 120, 'chunk_type': 'para'}),
#  Document(page_content='came to office--our country was hit by the worst pandemic and the worst ', metadata={'source': 'data/word.docx', 'chunk_number': 121, 'chunk_type': 'para'}),
#  Document(page_content='economic crisis in a century. Remember the fear. Record job losses. A ', metadata={'source': 'data/word.docx', 'chunk_number': 122, 'chunk_type': 'para'}),
#  Document(page_content='record spike in murder. A raging virus that would take more than 1 ', metadata={'source': 'data/word.docx', 'chunk_number': 123, 'chunk_type': 'para'}),
#  Document(page_content='million American lives and leave millions of loved ones behind. A ', metadata={'source': 'data/word.docx', 'chunk_number': 124, 'chunk_type': 'para'}),
#  Document(page_content='mental health crisis of isolation and loneliness. A President--my ', metadata={'source': 'data/word.docx', 'chunk_number': 125, 'chunk_type': 'para'}),
#  Document(page_content='predecessor--who failed the most basic duty any President owes the ', metadata={'source': 'data/word.docx', 'chunk_number': 126, 'chunk_type': 'para'}),
#  Document(page_content='American people--the duty to care. That is unforgivable.', metadata={'source': 'data/word.docx', 'chunk_number': 127, 'chunk_type': 'para'}),
#  Document(page_content='  I came to office determined to get us through one of the toughest ', metadata={'source': 'data/word.docx', 'chunk_number': 128, 'chunk_type': 'para'}),
#  Document(page_content="periods in our Nation's history. And we have. It doesn't make the ", metadata={'source': 'data/word.docx', 'chunk_number': 129, 'chunk_type': 'para'}),
#  Document(page_content='news--but in thousands of cities and towns--the American people are ', metadata={'source': 'data/word.docx', 'chunk_number': 130, 'chunk_type': 'para'}),
#  Document(page_content="writing the greatest comeback story never told. So let's tell that ", metadata={'source': 'data/word.docx', 'chunk_number': 131, 'chunk_type': 'para'}),
#  Document(page_content='story--here and now.', metadata={'source': 'data/word.docx', 'chunk_number': 132, 'chunk_type': 'para'}),
#  Document(page_content="  America's comeback is building a future of American possibilities--", metadata={'source': 'data/word.docx', 'chunk_number': 133, 'chunk_type': 'para'}),
#  Document(page_content='building an economy from the middle out and the bottom up--not the top ', metadata={'source': 'data/word.docx', 'chunk_number': 134, 'chunk_type': 'para'}),
#  Document(page_content='down--investing in all of America--in all Americans--to make sure ', metadata={'source': 'data/word.docx', 'chunk_number': 135, 'chunk_type': 'para'}),
#  Document(page_content='everyone has a fair shot and we leave no one behind!', metadata={'source': 'data/word.docx', 'chunk_number': 136, 'chunk_type': 'para'}),
#  Document(page_content='  The pandemic no longer controls our lives. The vaccines that saved us ', metadata={'source': 'data/word.docx', 'chunk_number': 137, 'chunk_type': 'para'}),
#  Document(page_content='from COVID are now being used to help beat cancer. Turning setback into ', metadata={'source': 'data/word.docx', 'chunk_number': 138, 'chunk_type': 'para'}),
#  Document(page_content="comeback. That's America!", metadata={'source': 'data/word.docx', 'chunk_number': 139, 'chunk_type': 'para'}),
#  Document(page_content='  I inherited an economy that was on the brink--now our economy is the ', metadata={'source': 'data/word.docx', 'chunk_number': 140, 'chunk_type': 'para'}),
#  Document(page_content="envy of the world! 15 million new jobs in just 3 years--that's a ", metadata={'source': 'data/word.docx', 'chunk_number': 141, 'chunk_type': 'para'}),
#  Document(page_content='record. Unemployment at 50-year lows. A record 16 million Americans are ', metadata={'source': 'data/word.docx', 'chunk_number': 142, 'chunk_type': 'para'}),
#  Document(page_content='starting small businesses and each one is an act of hope. With historic ', metadata={'source': 'data/word.docx', 'chunk_number': 143, 'chunk_type': 'para'}),
#  Document(page_content='job growth and small business growth for Black--Hispanic--and Asian-', metadata={'source': 'data/word.docx', 'chunk_number': 144, 'chunk_type': 'para'}),
#  Document(page_content='Americans.', metadata={'source': 'data/word.docx', 'chunk_number': 145, 'chunk_type': 'para'}),
#  Document(page_content='  800,000 new manufacturing jobs in America and counting. More people ', metadata={'source': 'data/word.docx', 'chunk_number': 146, 'chunk_type': 'para'}),
#  Document(page_content='have health insurance than ever before. The racial wealth gap is the ', metadata={'source': 'data/word.docx', 'chunk_number': 147, 'chunk_type': 'para'}),
#  Document(page_content="smallest it's been in 20 years. Wages keep going up and inflation keeps ", metadata={'source': 'data/word.docx', 'chunk_number': 148, 'chunk_type': 'para'}),
#  Document(page_content='coming down! Inflation has dropped from 9 percent to 3 percent--the ', metadata={'source': 'data/word.docx', 'chunk_number': 149, 'chunk_type': 'para'}),
#  Document(page_content='lowest in the world!', metadata={'source': 'data/word.docx', 'chunk_number': 150, 'chunk_type': 'para'}),
#  Document(page_content='  And now--instead of importing foreign products and exporting American', metadata={'source': 'data/word.docx', 'chunk_number': 151, 'chunk_type': 'para'}),
#  Document(page_content='[[Page S2274]]', metadata={'source': 'data/word.docx', 'chunk_number': 152, 'chunk_type': 'para'}),
#  Document(page_content="jobs--we're exporting American products and creating American jobs--", metadata={'source': 'data/word.docx', 'chunk_number': 153, 'chunk_type': 'para'}),
#  Document(page_content='right here in America. Where they belong! And the American people are ', metadata={'source': 'data/word.docx', 'chunk_number': 154, 'chunk_type': 'para'}),
#  Document(page_content='beginning to feel it.', metadata={'source': 'data/word.docx', 'chunk_number': 155, 'chunk_type': 'para'}),
#  Document(page_content='  Buy American has been the law of the land since the 1930s. Past ', metadata={'source': 'data/word.docx', 'chunk_number': 156, 'chunk_type': 'para'}),
#  Document(page_content='administrations--including my predecessor--failed to Buy American. Not. ', metadata={'source': 'data/word.docx', 'chunk_number': 157, 'chunk_type': 'para'}),
#  Document(page_content='Any. More. On my watch--Federal projects like helping to build American ', metadata={'source': 'data/word.docx', 'chunk_number': 158, 'chunk_type': 'para'}),
#  Document(page_content='roads--bridges--and highways will be made with American products--built ', metadata={'source': 'data/word.docx', 'chunk_number': 159, 'chunk_type': 'para'}),
#  Document(page_content='by American workers--creating good-paying American jobs!', metadata={'source': 'data/word.docx', 'chunk_number': 160, 'chunk_type': 'para'}),
#  Document(page_content='  Thanks to my CHIPS and Science Act--the United States is investing ', metadata={'source': 'data/word.docx', 'chunk_number': 161, 'chunk_type': 'para'}),
#  Document(page_content='more in research and development than ever before. During the ', metadata={'source': 'data/word.docx', 'chunk_number': 162, 'chunk_type': 'para'}),
#  Document(page_content='pandemic--a shortage of semiconductor chips drove up prices for ', metadata={'source': 'data/word.docx', 'chunk_number': 163, 'chunk_type': 'para'}),
#  Document(page_content='everything--from cell phones to automobiles. Well--instead of having to ', metadata={'source': 'data/word.docx', 'chunk_number': 164, 'chunk_type': 'para'}),
#  Document(page_content='import semiconductor chips--which America invented I might add--private ', metadata={'source': 'data/word.docx', 'chunk_number': 165, 'chunk_type': 'para'}),
#  Document(page_content='companies are now investing billions of dollars to build new chip ', metadata={'source': 'data/word.docx', 'chunk_number': 166, 'chunk_type': 'para'}),
#  Document(page_content='factories here in America! Creating tens of thousands of jobs--many of ', metadata={'source': 'data/word.docx', 'chunk_number': 167, 'chunk_type': 'para'}),
#  Document(page_content="them paying over $100,000 a year and don't require a college degree.", metadata={'source': 'data/word.docx', 'chunk_number': 168, 'chunk_type': 'para'}),
#  Document(page_content='  In fact--my policies have attracted $650 billion of private sector ', metadata={'source': 'data/word.docx', 'chunk_number': 169, 'chunk_type': 'para'}),
#  Document(page_content='investments in clean energy and advanced manufacturing--creating tens ', metadata={'source': 'data/word.docx', 'chunk_number': 170, 'chunk_type': 'para'}),
#  Document(page_content='of thousands of jobs here in America!', metadata={'source': 'data/word.docx', 'chunk_number': 171, 'chunk_type': 'para'}),
#  Document(page_content='  Thanks to our Bipartisan Infrastructure Law--46,000 new projects have ', metadata={'source': 'data/word.docx', 'chunk_number': 172, 'chunk_type': 'para'}),
#  Document(page_content='been announced across your communities modernizing our roads and ', metadata={'source': 'data/word.docx', 'chunk_number': 173, 'chunk_type': 'para'}),
#  Document(page_content='bridges--ports and airports--and public transit systems. Removing ', metadata={'source': 'data/word.docx', 'chunk_number': 174, 'chunk_type': 'para'}),
#  Document(page_content='poisonous lead pipes--so every child can drink clean water without risk ', metadata={'source': 'data/word.docx', 'chunk_number': 175, 'chunk_type': 'para'}),
#  Document(page_content='of getting brain damage.', metadata={'source': 'data/word.docx', 'chunk_number': 176, 'chunk_type': 'para'}),
#  Document(page_content='  Providing affordable--high speed Internet for every American--no ', metadata={'source': 'data/word.docx', 'chunk_number': 177, 'chunk_type': 'para'}),
#  Document(page_content='matter where you live. Urban--suburban--and rural communities--in red ', metadata={'source': 'data/word.docx', 'chunk_number': 178, 'chunk_type': 'para'}),
#  Document(page_content='States and blue. Record investments in tribal communities.', metadata={'source': 'data/word.docx', 'chunk_number': 179, 'chunk_type': 'para'}),
#  Document(page_content='  Because of my investments--family farms are better able to stay in ', metadata={'source': 'data/word.docx', 'chunk_number': 180, 'chunk_type': 'para'}),
#  Document(page_content="the family--and children and grandchildren won't have to leave home to ", metadata={'source': 'data/word.docx', 'chunk_number': 181, 'chunk_type': 'para'}),
#  Document(page_content="make a living. It's transformative.", metadata={'source': 'data/word.docx', 'chunk_number': 182, 'chunk_type': 'para'}),
#  Document(page_content='  A great comeback story--is Belvidere, Illinois. Home to an auto plant ', metadata={'source': 'data/word.docx', 'chunk_number': 183, 'chunk_type': 'para'}),
#  Document(page_content='for nearly 60 years. Before I came to office--the plant was on its way ', metadata={'source': 'data/word.docx', 'chunk_number': 184, 'chunk_type': 'para'}),
#  Document(page_content='to shutting down. Thousands of workers feared for their livelihoods. ', metadata={'source': 'data/word.docx', 'chunk_number': 185, 'chunk_type': 'para'}),
#  Document(page_content='Hope was fading. Then I was elected to office and we raised Belvidere ', metadata={'source': 'data/word.docx', 'chunk_number': 186, 'chunk_type': 'para'}),
#  Document(page_content='repeatedly--with the auto company--knowing unions make all the ', metadata={'source': 'data/word.docx', 'chunk_number': 187, 'chunk_type': 'para'}),
#  Document(page_content='difference.', metadata={'source': 'data/word.docx', 'chunk_number': 188, 'chunk_type': 'para'}),
#  Document(page_content='  The UAW worked like hell to keep the plant open and get those jobs ', metadata={'source': 'data/word.docx', 'chunk_number': 189, 'chunk_type': 'para'}),
#  Document(page_content='back. And together--we succeeded! Instead of an auto factory shutting ', metadata={'source': 'data/word.docx', 'chunk_number': 190, 'chunk_type': 'para'}),
#  Document(page_content='down an auto factory is re-opening--and a new state-of-the art battery ', metadata={'source': 'data/word.docx', 'chunk_number': 191, 'chunk_type': 'para'}),
#  Document(page_content='factory is being built to power those cars. Instead of a town being ', metadata={'source': 'data/word.docx', 'chunk_number': 192, 'chunk_type': 'para'}),
#  Document(page_content="left behind--it's a community moving forward again! Because instead of ", metadata={'source': 'data/word.docx', 'chunk_number': 193, 'chunk_type': 'para'}),
#  Document(page_content='watching auto jobs of the future go overseas--4,000 union workers--with ', metadata={'source': 'data/word.docx', 'chunk_number': 194, 'chunk_type': 'para'}),
#  Document(page_content='higher wages--will be building that future--here in America!', metadata={'source': 'data/word.docx', 'chunk_number': 195, 'chunk_type': 'para'}),
#  Document(page_content='  Here tonight--is UAW President Shawn Fain--a great friend and a great ', metadata={'source': 'data/word.docx', 'chunk_number': 196, 'chunk_type': 'para'}),
#  Document(page_content='labor leader. And Dawn Simms--a third generation UAW worker in ', metadata={'source': 'data/word.docx', 'chunk_number': 197, 'chunk_type': 'para'}),
#  Document(page_content='Belvidere. Shawn--I was proud to be the first President in American ', metadata={'source': 'data/word.docx', 'chunk_number': 198, 'chunk_type': 'para'}),
#  Document(page_content='history to walk a picket line. And today--Dawn has a job in her ', metadata={'source': 'data/word.docx', 'chunk_number': 199, 'chunk_type': 'para'}),
#  Document(page_content='hometown providing stability for her family and pride and dignity. ', metadata={'source': 'data/word.docx', 'chunk_number': 200, 'chunk_type': 'para'}),
#  Document(page_content="Showing once again Wall Street didn't build this country! The middle ", metadata={'source': 'data/word.docx', 'chunk_number': 201, 'chunk_type': 'para'}),
#  Document(page_content='class built this country! And unions built the middle class!', metadata={'source': 'data/word.docx', 'chunk_number': 202, 'chunk_type': 'para'}),
#  Document(page_content='  When Americans get knocked down--we get back up! We keep going! ', metadata={'source': 'data/word.docx', 'chunk_number': 203, 'chunk_type': 'para'}),
#  Document(page_content="That's America! That's you--the American people! It's because of you ", metadata={'source': 'data/word.docx', 'chunk_number': 204, 'chunk_type': 'para'}),
#  Document(page_content="America is coming back! It's because of you our future is brighter! And ", metadata={'source': 'data/word.docx', 'chunk_number': 205, 'chunk_type': 'para'}),
#  Document(page_content="it's because of you--That tonight--we can proudly say--the State of our ", metadata={'source': 'data/word.docx', 'chunk_number': 206, 'chunk_type': 'para'}),
#  Document(page_content='Union is strong and getting stronger!', metadata={'source': 'data/word.docx', 'chunk_number': 207, 'chunk_type': 'para'}),
#  Document(page_content='  Tonight--I want to talk about the future of possibilities that we can ', metadata={'source': 'data/word.docx', 'chunk_number': 208, 'chunk_type': 'para'}),
#  Document(page_content='build together. A future where the days of trickledown economics are ', metadata={'source': 'data/word.docx', 'chunk_number': 209, 'chunk_type': 'para'}),
#  Document(page_content='over and the wealthy and biggest corporations no longer get all the ', metadata={'source': 'data/word.docx', 'chunk_number': 210, 'chunk_type': 'para'}),
#  Document(page_content='breaks.', metadata={'source': 'data/word.docx', 'chunk_number': 211, 'chunk_type': 'para'}),
#  Document(page_content="  I grew up in a home where not a lot trickled down on my dad's kitchen ", metadata={'source': 'data/word.docx', 'chunk_number': 212, 'chunk_type': 'para'}),
#  Document(page_content="table. That's why I'm determined to turn things around so the middle ", metadata={'source': 'data/word.docx', 'chunk_number': 213, 'chunk_type': 'para'}),
#  Document(page_content='class does well--the poor have a way up and the wealthy still does ', metadata={'source': 'data/word.docx', 'chunk_number': 214, 'chunk_type': 'para'}),
#  Document(page_content="well. We all do well. And there's more to do to make sure you're ", metadata={'source': 'data/word.docx', 'chunk_number': 215, 'chunk_type': 'para'}),
#  Document(page_content="feeling the benefits of all we're doing.", metadata={'source': 'data/word.docx', 'chunk_number': 216, 'chunk_type': 'para'}),
#  Document(page_content="  Americans pay more for prescription drugs than anywhere else. It's ", metadata={'source': 'data/word.docx', 'chunk_number': 217, 'chunk_type': 'para'}),
#  Document(page_content="wrong and I'm ending it. With a law I proposed and signed and not one ", metadata={'source': 'data/word.docx', 'chunk_number': 218, 'chunk_type': 'para'}),
#  Document(page_content='Republican voted for--we finally beat Big Pharma!', metadata={'source': 'data/word.docx', 'chunk_number': 219, 'chunk_type': 'para'}),
#  Document(page_content='  Instead of paying $400 a month for insulin--seniors with diabetes ', metadata={'source': 'data/word.docx', 'chunk_number': 220, 'chunk_type': 'para'}),
#  Document(page_content='only have to pay $35 a month! And now--I want to cap the cost of ', metadata={'source': 'data/word.docx', 'chunk_number': 221, 'chunk_type': 'para'}),
#  Document(page_content='insulin at $35 a month for every American who needs it!', metadata={'source': 'data/word.docx', 'chunk_number': 222, 'chunk_type': 'para'}),
#  Document(page_content='  For years--people have talked about it--but I finally got it done--', metadata={'source': 'data/word.docx', 'chunk_number': 223, 'chunk_type': 'para'}),
#  Document(page_content='and gave Medicare the power to negotiate lower prices for prescription ', metadata={'source': 'data/word.docx', 'chunk_number': 224, 'chunk_type': 'para'}),
#  Document(page_content="drugs--just like the VA does for our veterans. That's not just saving ", metadata={'source': 'data/word.docx', 'chunk_number': 225, 'chunk_type': 'para'}),
#  Document(page_content="seniors money. It's saving taxpayers money--cutting the Federal deficit ", metadata={'source': 'data/word.docx', 'chunk_number': 226, 'chunk_type': 'para'}),
#  Document(page_content='by $160 billion--because Medicare will no longer have to pay exorbitant ', metadata={'source': 'data/word.docx', 'chunk_number': 227, 'chunk_type': 'para'}),
#  Document(page_content='prices to Big Pharma.', metadata={'source': 'data/word.docx', 'chunk_number': 228, 'chunk_type': 'para'}),
#  Document(page_content='  This year--Medicare is negotiating lower prices for some of the ', metadata={'source': 'data/word.docx', 'chunk_number': 229, 'chunk_type': 'para'}),
#  Document(page_content='costliest drugs on the market that treat everything from heart disease ', metadata={'source': 'data/word.docx', 'chunk_number': 230, 'chunk_type': 'para'}),
#  Document(page_content="to arthritis. Now it's time to go further and give Medicare the power ", metadata={'source': 'data/word.docx', 'chunk_number': 231, 'chunk_type': 'para'}),
#  Document(page_content='to negotiate lower prices for 500 drugs over the next decade. That will ', metadata={'source': 'data/word.docx', 'chunk_number': 232, 'chunk_type': 'para'}),
#  Document(page_content='not only save lives--it will save taxpayers another $200 billion!', metadata={'source': 'data/word.docx', 'chunk_number': 233, 'chunk_type': 'para'}),
#  Document(page_content='  Starting next year--that same law caps total prescription drug costs ', metadata={'source': 'data/word.docx', 'chunk_number': 234, 'chunk_type': 'para'}),
#  Document(page_content='for seniors on Medicare at $2,000 a year--even for expensive cancer ', metadata={'source': 'data/word.docx', 'chunk_number': 235, 'chunk_type': 'para'}),
#  Document(page_content='drugs that can cost $10,000--$12,000--$15,000 a year. Now--I want to ', metadata={'source': 'data/word.docx', 'chunk_number': 236, 'chunk_type': 'para'}),
#  Document(page_content='cap prescription drug costs at $2,000 a year--for everyone!', metadata={'source': 'data/word.docx', 'chunk_number': 237, 'chunk_type': 'para'}),
#  Document(page_content='  Folks--the Affordable Care Act is still a very big deal. Over one ', metadata={'source': 'data/word.docx', 'chunk_number': 238, 'chunk_type': 'para'}),
#  Document(page_content='hundred million of you can no longer be denied health insurance because ', metadata={'source': 'data/word.docx', 'chunk_number': 239, 'chunk_type': 'para'}),
#  Document(page_content='of pre-existing conditions. But my predecessor--and many in this ', metadata={'source': 'data/word.docx', 'chunk_number': 240, 'chunk_type': 'para'}),
#  Document(page_content='chamber--want to take that protection away by repealing the Affordable ', metadata={'source': 'data/word.docx', 'chunk_number': 241, 'chunk_type': 'para'}),
#  Document(page_content="Care Act. I won't let that happen! We stopped you 50 times before--and ", metadata={'source': 'data/word.docx', 'chunk_number': 242, 'chunk_type': 'para'}),
#  Document(page_content='we will stop you again!', metadata={'source': 'data/word.docx', 'chunk_number': 243, 'chunk_type': 'para'}),
#  Document(page_content='  In fact--I am protecting it and expanding it. I enacted tax credits--', metadata={'source': 'data/word.docx', 'chunk_number': 244, 'chunk_type': 'para'}),
#  Document(page_content='that save $800 per person--per year--reducing health care premiums for ', metadata={'source': 'data/word.docx', 'chunk_number': 245, 'chunk_type': 'para'}),
#  Document(page_content='millions of working families. Those tax credits expire next year. I ', metadata={'source': 'data/word.docx', 'chunk_number': 246, 'chunk_type': 'para'}),
#  Document(page_content='want to make those savings permanent!', metadata={'source': 'data/word.docx', 'chunk_number': 247, 'chunk_type': 'para'}),
#  Document(page_content="  Women are more than half of our population but research on women's ", metadata={'source': 'data/word.docx', 'chunk_number': 248, 'chunk_type': 'para'}),
#  Document(page_content="health has always been underfunded. That's why we're launching the ", metadata={'source': 'data/word.docx', 'chunk_number': 249, 'chunk_type': 'para'}),
#  Document(page_content="first-ever White House Initiative on Women's Health Research--led by ", metadata={'source': 'data/word.docx', 'chunk_number': 250, 'chunk_type': 'para'}),
#  Document(page_content='Jill--who is doing an incredible job as First Lady. Pass my plan for ', metadata={'source': 'data/word.docx', 'chunk_number': 251, 'chunk_type': 'para'}),
#  Document(page_content="$12 billion--to transform women's health research and benefit millions ", metadata={'source': 'data/word.docx', 'chunk_number': 252, 'chunk_type': 'para'}),
#  Document(page_content='of lives across America!', metadata={'source': 'data/word.docx', 'chunk_number': 253, 'chunk_type': 'para'}),
#  Document(page_content='  I know the cost of housing is so important to you. If inflation keeps ', metadata={'source': 'data/word.docx', 'chunk_number': 254, 'chunk_type': 'para'}),
#  Document(page_content="coming down--mortgage rates--will come down as well. But I'm not ", metadata={'source': 'data/word.docx', 'chunk_number': 255, 'chunk_type': 'para'}),
#  Document(page_content='waiting. I want to provide an annual tax credit that will give ', metadata={'source': 'data/word.docx', 'chunk_number': 256, 'chunk_type': 'para'}),
#  Document(page_content='Americans $400 a month--for the next 2 years--as mortgage rates come ', metadata={'source': 'data/word.docx', 'chunk_number': 257, 'chunk_type': 'para'}),
#  Document(page_content='down--to put toward their mortgage when they buy a first home or trade ', metadata={'source': 'data/word.docx', 'chunk_number': 258, 'chunk_type': 'para'}),
#  Document(page_content='up for a little more space.', metadata={'source': 'data/word.docx', 'chunk_number': 259, 'chunk_type': 'para'}),
#  Document(page_content='  My Administration is also eliminating title insurance fees for ', metadata={'source': 'data/word.docx', 'chunk_number': 260, 'chunk_type': 'para'}),
#  Document(page_content='federally backed mortgages. When you refinance your home--this can save ', metadata={'source': 'data/word.docx', 'chunk_number': 261, 'chunk_type': 'para'}),
#  Document(page_content="you $1,000 or more. For millions of renters--we're cracking down on big ", metadata={'source': 'data/word.docx', 'chunk_number': 262, 'chunk_type': 'para'}),
#  Document(page_content='landlords who break antitrust laws by price-fixing and driving up ', metadata={'source': 'data/word.docx', 'chunk_number': 263, 'chunk_type': 'para'}),
#  Document(page_content="rents. I've cut red tape--so more builders can get Federal financing--", metadata={'source': 'data/word.docx', 'chunk_number': 264, 'chunk_type': 'para'}),
#  Document(page_content='which is already helping build a record 1.7 million housing units ', metadata={'source': 'data/word.docx', 'chunk_number': 265, 'chunk_type': 'para'}),
#  Document(page_content='nationwide. Now pass my plan to build and renovate 2 million affordable ', metadata={'source': 'data/word.docx', 'chunk_number': 266, 'chunk_type': 'para'}),
#  Document(page_content='homes--and bring those rents down!', metadata={'source': 'data/word.docx', 'chunk_number': 267, 'chunk_type': 'para'}),
#  Document(page_content='  To remain the strongest economy in the world--we need the best ', metadata={'source': 'data/word.docx', 'chunk_number': 268, 'chunk_type': 'para'}),
#  Document(page_content='education system in the world. I want to give every child a good start ', metadata={'source': 'data/word.docx', 'chunk_number': 269, 'chunk_type': 'para'}),
#  Document(page_content='by providing access to pre-school for 3- and 4-year-olds. Studies show ', metadata={'source': 'data/word.docx', 'chunk_number': 270, 'chunk_type': 'para'}),
#  Document(page_content='that children who go to pre-school are nearly 50 percent more likely to ', metadata={'source': 'data/word.docx', 'chunk_number': 271, 'chunk_type': 'para'}),
#  Document(page_content='finish high school and go on to earn a 2- or 4-year degree no matter ', metadata={'source': 'data/word.docx', 'chunk_number': 272, 'chunk_type': 'para'}),
#  Document(page_content='their background. I want to expand high-quality tutoring and summer ', metadata={'source': 'data/word.docx', 'chunk_number': 273, 'chunk_type': 'para'}),
#  Document(page_content='learning time and see to it that every child learns to read by third ', metadata={'source': 'data/word.docx', 'chunk_number': 274, 'chunk_type': 'para'}),
#  Document(page_content='grade.', metadata={'source': 'data/word.docx', 'chunk_number': 275, 'chunk_type': 'para'}),
#  Document(page_content="  I'm also connecting local businesses and high schools so students get ", metadata={'source': 'data/word.docx', 'chunk_number': 276, 'chunk_type': 'para'}),
#  Document(page_content='hands-on experience and a path to a good-paying job whether or not they ', metadata={'source': 'data/word.docx', 'chunk_number': 277, 'chunk_type': 'para'}),
#  Document(page_content="go to college. And I want to make college more affordable. Let's ", metadata={'source': 'data/word.docx', 'chunk_number': 278, 'chunk_type': 'para'}),
#  Document(page_content='continue increasing Pell Grants for working- and middle-class families ', metadata={'source': 'data/word.docx', 'chunk_number': 279, 'chunk_type': 'para'}),
#  Document(page_content='and increase our record investments in HBCUs and Minority-Serving ', metadata={'source': 'data/word.docx', 'chunk_number': 280, 'chunk_type': 'para'}),
# ...
#  Document(page_content='American President to visit Israel in wartime.', metadata={'source': 'data/word.docx', 'chunk_number': 529, 'chunk_type': 'para'}),
#  Document(page_content="  There is no other path that guarantees Israel's security--and ", metadata={'source': 'data/word.docx', 'chunk_number': 530, 'chunk_type': 'para'}),
#  Document(page_content='democracy. There is no other path that guarantees Palestinians can live ', metadata={'source': 'data/word.docx', 'chunk_number': 531, 'chunk_type': 'para'}),
#  Document(page_content='with peace and dignity. There is no other path that guarantees peace ', metadata={'source': 'data/word.docx', 'chunk_number': 532, 'chunk_type': 'para'}),
#  Document(page_content='between Israel and all of its Arab neighbors--including Saudi Arabia.', metadata={'source': 'data/word.docx', 'chunk_number': 533, 'chunk_type': 'para'}),
#  Document(page_content='  Creating stability in the Middle East also means containing the ', metadata={'source': 'data/word.docx', 'chunk_number': 534, 'chunk_type': 'para'}),
#  Document(page_content="threat posed by Iran. That's why I built a coalition of more than a ", metadata={'source': 'data/word.docx', 'chunk_number': 535, 'chunk_type': 'para'}),
#  Document(page_content='dozen countries to defend international shipping and freedom of ', metadata={'source': 'data/word.docx', 'chunk_number': 536, 'chunk_type': 'para'}),
#  Document(page_content="navigation in the Red Sea. I've ordered strikes to degrade Houthi ", metadata={'source': 'data/word.docx', 'chunk_number': 537, 'chunk_type': 'para'}),
#  Document(page_content='capabilities and defend United States Forces in the region. As ', metadata={'source': 'data/word.docx', 'chunk_number': 538, 'chunk_type': 'para'}),
#  Document(page_content='Commander in Chief--I will not hesitate, to direct further measures to ', metadata={'source': 'data/word.docx', 'chunk_number': 539, 'chunk_type': 'para'}),
#  Document(page_content='protect our people and military personnel.', metadata={'source': 'data/word.docx', 'chunk_number': 540, 'chunk_type': 'para'}),
#  Document(page_content="  For years--all I've heard from my Republican friends--and so many ", metadata={'source': 'data/word.docx', 'chunk_number': 541, 'chunk_type': 'para'}),
#  Document(page_content="others--is that China's on the rise--and America is falling behind. ", metadata={'source': 'data/word.docx', 'chunk_number': 542, 'chunk_type': 'para'}),
#  Document(page_content="They've got it backward. America is rising. We have the best economy in ", metadata={'source': 'data/word.docx', 'chunk_number': 543, 'chunk_type': 'para'}),
#  Document(page_content="the world. Since I've come to office--our GDP is up. And our trade ", metadata={'source': 'data/word.docx', 'chunk_number': 544, 'chunk_type': 'para'}),
#  Document(page_content='deficit with China is down to the lowest point in over a decade.', metadata={'source': 'data/word.docx', 'chunk_number': 545, 'chunk_type': 'para'}),
#  Document(page_content="  We're standing against China's unfair economic practices. And ", metadata={'source': 'data/word.docx', 'chunk_number': 546, 'chunk_type': 'para'}),
#  Document(page_content="standing up for peace and stability across the Taiwan Strait. I've ", metadata={'source': 'data/word.docx', 'chunk_number': 547, 'chunk_type': 'para'}),
#  Document(page_content="revitalized our partnerships and alliances in the Pacific. I've made ", metadata={'source': 'data/word.docx', 'chunk_number': 548, 'chunk_type': 'para'}),
#  Document(page_content="sure that the most advanced American technologies can't be used in ", metadata={'source': 'data/word.docx', 'chunk_number': 549, 'chunk_type': 'para'}),
#  Document(page_content="China's weapons.", metadata={'source': 'data/word.docx', 'chunk_number': 550, 'chunk_type': 'para'}),
#  Document(page_content='  Frankly--for all his tough talk on China--it never occurred to my ', metadata={'source': 'data/word.docx', 'chunk_number': 551, 'chunk_type': 'para'}),
#  Document(page_content='predecessor to do that. We want competition', metadata={'source': 'data/word.docx', 'chunk_number': 552, 'chunk_type': 'para'}),
#  Document(page_content='[[Page S2277]]', metadata={'source': 'data/word.docx', 'chunk_number': 553, 'chunk_type': 'para'}),
#  Document(page_content='with China--but not conflict. And we are in a stronger position to win ', metadata={'source': 'data/word.docx', 'chunk_number': 554, 'chunk_type': 'para'}),
#  Document(page_content='the competition for the 2lst Century against China--or anyone else for ', metadata={'source': 'data/word.docx', 'chunk_number': 555, 'chunk_type': 'para'}),
#  Document(page_content='that matter.', metadata={'source': 'data/word.docx', 'chunk_number': 556, 'chunk_type': 'para'}),
#  Document(page_content="  Here at home--I've signed over 400 bipartisan bills. But there's more ", metadata={'source': 'data/word.docx', 'chunk_number': 557, 'chunk_type': 'para'}),
#  Document(page_content='to do to pass my Unity Agenda. Strengthen penalties on fentanyl ', metadata={'source': 'data/word.docx', 'chunk_number': 558, 'chunk_type': 'para'}),
#  Document(page_content='trafficking. Pass bipartisan privacy legislation to protect our ', metadata={'source': 'data/word.docx', 'chunk_number': 559, 'chunk_type': 'para'}),
#  Document(page_content='children online--harness the promise of A.I. and protect us from its ', metadata={'source': 'data/word.docx', 'chunk_number': 560, 'chunk_type': 'para'}),
#  Document(page_content='peril--ban A.I. voice impersonation--and more!', metadata={'source': 'data/word.docx', 'chunk_number': 561, 'chunk_type': 'para'}),
#  Document(page_content='  And keep our one truly sacred obligation: To train and equip those we ', metadata={'source': 'data/word.docx', 'chunk_number': 562, 'chunk_type': 'para'}),
#  Document(page_content="send into harm's way and care for them and their families when they ", metadata={'source': 'data/word.docx', 'chunk_number': 563, 'chunk_type': 'para'}),
#  Document(page_content="come home--and when they don't. That's why I signed the PACT Act--one ", metadata={'source': 'data/word.docx', 'chunk_number': 564, 'chunk_type': 'para'}),
#  Document(page_content='of the most significant laws ever--helping millions of veterans who ', metadata={'source': 'data/word.docx', 'chunk_number': 565, 'chunk_type': 'para'}),
#  Document(page_content='were exposed to toxins and who now are battling more than 100 cancers. ', metadata={'source': 'data/word.docx', 'chunk_number': 566, 'chunk_type': 'para'}),
#  Document(page_content="Many of them didn't come home. We owe them and their families.", metadata={'source': 'data/word.docx', 'chunk_number': 567, 'chunk_type': 'para'}),
#  Document(page_content='  And we owe it to ourselves to keep supporting our new health research ', metadata={'source': 'data/word.docx', 'chunk_number': 568, 'chunk_type': 'para'}),
#  Document(page_content='agency called ARPA-H--and remind us that we can do big things like end ', metadata={'source': 'data/word.docx', 'chunk_number': 569, 'chunk_type': 'para'}),
#  Document(page_content='cancer as we know it!', metadata={'source': 'data/word.docx', 'chunk_number': 570, 'chunk_type': 'para'}),
#  Document(page_content="  Let me close with this. I know I may not look like it--but I've been ", metadata={'source': 'data/word.docx', 'chunk_number': 571, 'chunk_type': 'para'}),
#  Document(page_content='around a while. And when you get to my age--certain things become ', metadata={'source': 'data/word.docx', 'chunk_number': 572, 'chunk_type': 'para'}),
#  Document(page_content='clearer than ever before.', metadata={'source': 'data/word.docx', 'chunk_number': 573, 'chunk_type': 'para'}),
#  Document(page_content="  I know the American story. Again and again--I've seen the contest ", metadata={'source': 'data/word.docx', 'chunk_number': 574, 'chunk_type': 'para'}),
#  Document(page_content='between competing forces in the battle for the soul of our Nation. ', metadata={'source': 'data/word.docx', 'chunk_number': 575, 'chunk_type': 'para'}),
#  Document(page_content='Between those who want to pull America back to the past and those who ', metadata={'source': 'data/word.docx', 'chunk_number': 576, 'chunk_type': 'para'}),
#  Document(page_content='want to move America into the future.', metadata={'source': 'data/word.docx', 'chunk_number': 577, 'chunk_type': 'para'}),
#  Document(page_content='  My lifetime has taught me to embrace freedom and democracy. A future ', metadata={'source': 'data/word.docx', 'chunk_number': 578, 'chunk_type': 'para'}),
#  Document(page_content='based on the core values that have defined America. Honesty. Decency. ', metadata={'source': 'data/word.docx', 'chunk_number': 579, 'chunk_type': 'para'}),
#  Document(page_content='Dignity. Equality. To respect everyone. To give everyone a fair shot. ', metadata={'source': 'data/word.docx', 'chunk_number': 580, 'chunk_type': 'para'}),
#  Document(page_content='To give hate no safe harbor.', metadata={'source': 'data/word.docx', 'chunk_number': 581, 'chunk_type': 'para'}),
#  Document(page_content='  Now--some other people my age see a different story. An American ', metadata={'source': 'data/word.docx', 'chunk_number': 582, 'chunk_type': 'para'}),
#  Document(page_content='story of resentment--revenge--and retribution.', metadata={'source': 'data/word.docx', 'chunk_number': 583, 'chunk_type': 'para'}),
#  Document(page_content="  That's not me. I was born amid World War II--when America stood for ", metadata={'source': 'data/word.docx', 'chunk_number': 584, 'chunk_type': 'para'}),
#  Document(page_content='freedom in the world. I grew up in Scranton, Pennsylvania, and ', metadata={'source': 'data/word.docx', 'chunk_number': 585, 'chunk_type': 'para'}),
#  Document(page_content='Claymont, Delaware, among working people who built this country.', metadata={'source': 'data/word.docx', 'chunk_number': 586, 'chunk_type': 'para'}),
#  Document(page_content='  I watched in horror as two of my heroes--Dr. King and Bobby Kennedy--', metadata={'source': 'data/word.docx', 'chunk_number': 587, 'chunk_type': 'para'}),
#  Document(page_content='were assassinated--and their legacies inspired me to pursue a career in ', metadata={'source': 'data/word.docx', 'chunk_number': 588, 'chunk_type': 'para'}),
#  Document(page_content='service. A public defender--county councilman--elected United States ', metadata={'source': 'data/word.docx', 'chunk_number': 589, 'chunk_type': 'para'}),
#  Document(page_content='Senator at 29--then Vice President to our first Black President--now ', metadata={'source': 'data/word.docx', 'chunk_number': 590, 'chunk_type': 'para'}),
#  Document(page_content='President with our first woman Vice President.', metadata={'source': 'data/word.docx', 'chunk_number': 591, 'chunk_type': 'para'}),
#  Document(page_content="  In my career--I've been told I'm too young--and I'm too old. Whether ", metadata={'source': 'data/word.docx', 'chunk_number': 592, 'chunk_type': 'para'}),
#  Document(page_content="young or old--I've always known what endures. Our North Star. The very ", metadata={'source': 'data/word.docx', 'chunk_number': 593, 'chunk_type': 'para'}),
#  Document(page_content='idea of America--that we are all created equal and deserve to be ', metadata={'source': 'data/word.docx', 'chunk_number': 594, 'chunk_type': 'para'}),
#  Document(page_content='treated equally throughout our lives.', metadata={'source': 'data/word.docx', 'chunk_number': 595, 'chunk_type': 'para'}),
#  Document(page_content="  We've never fully lived up to that idea--but we've never walked away ", metadata={'source': 'data/word.docx', 'chunk_number': 596, 'chunk_type': 'para'}),
#  Document(page_content="from it either. And I won't walk away from it now.", metadata={'source': 'data/word.docx', 'chunk_number': 597, 'chunk_type': 'para'}),
#  Document(page_content="  My fellow Americans--the issue facing our Nation isn't how old we ", metadata={'source': 'data/word.docx', 'chunk_number': 598, 'chunk_type': 'para'}),
#  Document(page_content="are--it's how old are our ideas? Hate--anger--revenge--retribution--are ", metadata={'source': 'data/word.docx', 'chunk_number': 599, 'chunk_type': 'para'}),
#  Document(page_content="among the oldest of ideas. But you can't lead America with ancient ", metadata={'source': 'data/word.docx', 'chunk_number': 600, 'chunk_type': 'para'}),
#  Document(page_content='ideas that only take us back.', metadata={'source': 'data/word.docx', 'chunk_number': 601, 'chunk_type': 'para'}),
#  Document(page_content='  To lead America--the land of possibilities--you need a vision for the ', metadata={'source': 'data/word.docx', 'chunk_number': 602, 'chunk_type': 'para'}),
#  Document(page_content="future of what America can and should be. Tonight--you've heard mine.", metadata={'source': 'data/word.docx', 'chunk_number': 603, 'chunk_type': 'para'}),
#  Document(page_content='  I see a future where we defend democracy--not diminish it. I see a ', metadata={'source': 'data/word.docx', 'chunk_number': 604, 'chunk_type': 'para'}),
#  Document(page_content='future where we restore the right to choose and protect other ', metadata={'source': 'data/word.docx', 'chunk_number': 605, 'chunk_type': 'para'}),
#  Document(page_content='freedoms--not take them away.', metadata={'source': 'data/word.docx', 'chunk_number': 606, 'chunk_type': 'para'}),
#  Document(page_content='  I see a future where the middle class finally has a fair shot--and ', metadata={'source': 'data/word.docx', 'chunk_number': 607, 'chunk_type': 'para'}),
#  Document(page_content='the wealthy finally have to pay their fair share in taxes.', metadata={'source': 'data/word.docx', 'chunk_number': 608, 'chunk_type': 'para'}),
#  Document(page_content='  I see a future where we save the planet from the climate crisis and ', metadata={'source': 'data/word.docx', 'chunk_number': 609, 'chunk_type': 'para'}),
#  Document(page_content='our country from gun violence.', metadata={'source': 'data/word.docx', 'chunk_number': 610, 'chunk_type': 'para'}),
#  Document(page_content='  Above all--I see a future for all Americans! I see a country for all ', metadata={'source': 'data/word.docx', 'chunk_number': 611, 'chunk_type': 'para'}),
#  Document(page_content='Americans! And I will always be a President for all Americans! Because ', metadata={'source': 'data/word.docx', 'chunk_number': 612, 'chunk_type': 'para'}),
#  Document(page_content="I believe in America! I believe in you--the American people. You're the ", metadata={'source': 'data/word.docx', 'chunk_number': 613, 'chunk_type': 'para'}),
#  Document(page_content="reason I've never been more optimistic about our future!", metadata={'source': 'data/word.docx', 'chunk_number': 614, 'chunk_type': 'para'}),
#  Document(page_content="  So let's build that future together! Let's remember who we are! We ", metadata={'source': 'data/word.docx', 'chunk_number': 615, 'chunk_type': 'para'}),
#  Document(page_content='are the United States of America. There is nothing beyond our capacity ', metadata={'source': 'data/word.docx', 'chunk_number': 616, 'chunk_type': 'para'}),
#  Document(page_content='when we act together!', metadata={'source': 'data/word.docx', 'chunk_number': 617, 'chunk_type': 'para'}),
#  Document(page_content='  May God bless you all.', metadata={'source': 'data/word.docx', 'chunk_number': 618, 'chunk_type': 'para'}),
#  Document(page_content='  May God protect our troops.', metadata={'source': 'data/word.docx', 'chunk_number': 619, 'chunk_type': 'para'}),
#  Document(page_content='                                                 Joseph R. Biden, Jr.  ', metadata={'source': 'data/word.docx', 'chunk_number': 620, 'chunk_type': 'para'}),
#  Document(page_content='The White House, March 7, 2024.', metadata={'source': 'data/word.docx', 'chunk_number': 621, 'chunk_type': 'para'}),
#  Document(page_content='                          ____________________', metadata={'source': 'data/word.docx', 'chunk_number': 622, 'chunk_type': 'para'})]

# %%
# combine the output of different parsers
# each element is of type langchain document
combined_doc = docs + doc_splits
# Out:
# 637

# %%
# create a vector store as before
vectorstore = Neo4jVector.from_documents(
    documents=combined_doc,
    url=config["neo4j_url"],
    username=config["neo4j_username"],
    password=config["neo4j_password"],
    embedding=embeddings,
    index_name="parsers_trial",
    node_label="parsersTrial",
    pre_delete_collection=False,
)

# %%
retriever = vectorstore.as_retriever()
retriever.invoke("God")
# Out:
# [Document(page_content='\nr/MachineLearning\n \n \n \n    \n \n \nA chip\nA close button', metadata={'chunk_number': 3, 'source': 'data/website.html', 'chunk_type': 'para'}),
#  Document(page_content='predecessor to do that. We want competition', metadata={'chunk_number': 552, 'source': 'data/word.docx', 'chunk_type': 'para'}),
#  Document(page_content='[Senate]', metadata={'chunk_number': 1, 'source': 'data/word.docx', 'chunk_type': 'para'}),
#  Document(page_content='make it fair!', metadata={'chunk_number': 310, 'source': 'data/word.docx', 'chunk_type': 'para'})]

# %%
# this uses the document_chain from above
retrieval_chain = create_retrieval_chain(retriever, document_chain)
response = retrieval_chain.invoke({"input": "What does it mean to survive in society?"})

# %%
print("Response:", response)
print()
print("Answer:", response["answer"])
print()
# We have a list of references to documents that were used to generate the answer
print("Context:", response["context"])
# Out:
# Response: {'input': 'What does it mean to survive in society?', 'context': [Document(page_content="reason I've never been more optimistic about our future!", metadata={'chunk_number': 614, 'source': 'data/word.docx', 'chunk_type': 'para'}), Document(page_content='peril--ban A.I. voice impersonation--and more!', metadata={'chunk_number': 561, 'source': 'data/word.docx', 'chunk_type': 'para'}), Document(page_content='cancer as we know it!', metadata={'chunk_number': 570, 'source': 'data/word.docx', 'chunk_type': 'para'}), Document(page_content='Federal income taxes. Not anymore!', metadata={'chunk_number': 319, 'source': 'data/word.docx', 'chunk_type': 'para'})], 'answer': 'Based on the provided context, it seems that "survive" refers to living with minimal financial burdens, specifically mentioning Federal income taxes. The speaker is expressing optimism about their future and implies that they will no longer have to worry about these financial constraints.'}
#
# Answer: Based on the provided context, it seems that "survive" refers to living with minimal financial burdens, specifically mentioning Federal income taxes. The speaker is expressing optimism about their future and implies that they will no longer have to worry about these financial constraints.
#
# Context: [Document(page_content="reason I've never been more optimistic about our future!", metadata={'chunk_number': 614, 'source': 'data/word.docx', 'chunk_type': 'para'}), Document(page_content='peril--ban A.I. voice impersonation--and more!', metadata={'chunk_number': 561, 'source': 'data/word.docx', 'chunk_type': 'para'}), Document(page_content='cancer as we know it!', metadata={'chunk_number': 570, 'source': 'data/word.docx', 'chunk_type': 'para'}), Document(page_content='Federal income taxes. Not anymore!', metadata={'chunk_number': 319, 'source': 'data/word.docx', 'chunk_type': 'para'})]

# %% [markdown]
# ## Following this, we can define our own data retrieval process using the LangGraph workflow.
